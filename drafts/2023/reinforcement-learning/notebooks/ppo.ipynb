# %%
# !pip install "sb3_contrib>=2.0.0a1" --upgrade
# Out:
# Requirement already satisfied: sb3_contrib>=2.0.0a1 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (2.0.0a4)
# Requirement already satisfied: stable-baselines3>=2.0.0a4 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from sb3_contrib>=2.0.0a1) (2.0.0a5)
# Requirement already satisfied: gymnasium==0.28.1 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (0.28.1)
# Requirement already satisfied: numpy in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (1.24.2)
# Requirement already satisfied: torch>=1.11 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (2.0.0)
# Requirement already satisfied: cloudpickle in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (2.2.1)
# Requirement already satisfied: pandas in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (2.0.0)
# Requirement already satisfied: matplotlib in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (3.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (0.0.4)
# Requirement already satisfied: filelock in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from torch>=1.11->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (3.11.0)
# Requirement already satisfied: sympy in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from torch>=1.11->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (1.11.1)
# Requirement already satisfied: networkx in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from torch>=1.11->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (3.1)
# Requirement already satisfied: jinja2 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from torch>=1.11->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from pandas->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from pandas->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from jinja2->torch>=1.11->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/jackmckew/miniconda3/envs/d3/lib/python3.11/site-packages (from sympy->torch>=1.11->stable-baselines3>=2.0.0a4->sb3_contrib>=2.0.0a1) (1.3.0)

# %%
import gymnasium as gym

from stable_baselines3 import A2C

env = gym.make("CartPole-v1",render_mode='human')

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render()
    # VecEnv resets automatically
    # if done:
    #   obs = vec_env.reset()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 24.2     |
# |    ep_rew_mean        | 24.2     |
# | time/                 |          |
# |    fps                | 45       |
# |    iterations         | 100      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.68    |
# |    explained_variance | -0.747   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.6      |
# |    value_loss         | 11.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.9     |
# |    ep_rew_mean        | 28.9     |
# | time/                 |          |
# |    fps                | 46       |
# |    iterations         | 200      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | -0.0315  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.61     |
# |    value_loss         | 7.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 32.8     |
# |    ep_rew_mean        | 32.8     |
# | time/                 |          |
# |    fps                | 44       |
# |    iterations         | 300      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.616   |
# |    explained_variance | 0.00426  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.58     |
# |    value_loss         | 6.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37       |
# |    ep_rew_mean        | 37       |
# | time/                 |          |
# |    fps                | 43       |
# |    iterations         | 400      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.478   |
# |    explained_variance | 0.0591   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.51     |
# |    value_loss         | 5.56     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 38.5     |
# |    ep_rew_mean        | 38.5     |
# | time/                 |          |
# |    fps                | 44       |
# |    iterations         | 500      |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.452   |
# |    explained_variance | 0.0191   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 2.27     |
# |    value_loss         | 5.15     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.2     |
# |    ep_rew_mean        | 44.2     |
# | time/                 |          |
# |    fps                | 44       |
# |    iterations         | 600      |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.631   |
# |    explained_variance | 0.00261  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.02     |
# |    value_loss         | 4.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.8     |
# |    ep_rew_mean        | 46.8     |
# | time/                 |          |
# |    fps                | 44       |
# |    iterations         | 700      |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.64    |
# |    explained_variance | -0.0017  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.08     |
# |    value_loss         | 4.07     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49.3     |
# |    ep_rew_mean        | 49.3     |
# | time/                 |          |
# |    fps                | 44       |
# |    iterations         | 800      |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.601   |
# |    explained_variance | -0.00048 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.2      |
# |    value_loss         | 3.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 54.6     |
# |    ep_rew_mean        | 54.6     |
# | time/                 |          |
# |    fps                | 45       |
# |    iterations         | 900      |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.577   |
# |    explained_variance | -0.00021 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.973    |
# |    value_loss         | 3.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 57.8     |
# |    ep_rew_mean        | 57.8     |
# | time/                 |          |
# |    fps                | 45       |
# |    iterations         | 1000     |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.504   |
# |    explained_variance | 0.00031  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.15     |
# |    value_loss         | 2.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 62.9     |
# |    ep_rew_mean        | 62.9     |
# | time/                 |          |
# |    fps                | 44       |
# |    iterations         | 1100     |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.609   |
# |    explained_variance | 0.000187 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.541    |
# |    value_loss         | 2.11     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 66.5     |
# |    ep_rew_mean        | 66.5     |
# | time/                 |          |
# |    fps                | 45       |
# |    iterations         | 1200     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.55    |
# |    explained_variance | 0.000479 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.521    |
# |    value_loss         | 1.71     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 71.4     |
# |    ep_rew_mean        | 71.4     |
# | time/                 |          |
# |    fps                | 45       |
# |    iterations         | 1300     |
# |    time_elapsed       | 143      |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.22    |
# |    explained_variance | 0.000723 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -92.4    |
# |    value_loss         | 3.75e+03 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 74.8      |
# |    ep_rew_mean        | 74.8      |
# | time/                 |           |
# |    fps                | 45        |
# |    iterations         | 1400      |
# |    time_elapsed       | 154       |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.572    |
# |    explained_variance | -0.000135 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.43      |
# |    value_loss         | 1.05      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 79.1      |
# |    ep_rew_mean        | 79.1      |
# | time/                 |           |
# |    fps                | 45        |
# |    iterations         | 1500      |
# |    time_elapsed       | 165       |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.597    |
# |    explained_variance | -8.68e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 0.362     |
# |    value_loss         | 0.781     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 82        |
# |    ep_rew_mean        | 82        |
# | time/                 |           |
# |    fps                | 45        |
# |    iterations         | 1600      |
# |    time_elapsed       | 176       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.402    |
# |    explained_variance | -0.000338 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 0.309     |
# |    value_loss         | 0.553     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.1     |
# |    ep_rew_mean        | 84.1     |
# | time/                 |          |
# |    fps                | 45       |
# |    iterations         | 1700     |
# |    time_elapsed       | 187      |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.579   |
# |    explained_variance | 6.75e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.305    |
# |    value_loss         | 0.366    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 88.6      |
# |    ep_rew_mean        | 88.6      |
# | time/                 |           |
# |    fps                | 45        |
# |    iterations         | 1800      |
# |    time_elapsed       | 199       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.454    |
# |    explained_variance | -0.000263 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.326     |
# |    value_loss         | 0.219     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 92.1      |
# |    ep_rew_mean        | 92.1      |
# | time/                 |           |
# |    fps                | 45        |
# |    iterations         | 1900      |
# |    time_elapsed       | 210       |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -0.538    |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.148     |
# |    value_loss         | 0.108     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 95.8      |
# |    ep_rew_mean        | 95.8      |
# | time/                 |           |
# |    fps                | 44        |
# |    iterations         | 2000      |
# |    time_elapsed       | 223       |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.442    |
# |    explained_variance | -0.000212 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.0652    |
# |    value_loss         | 0.0373    |
# -------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 15
#      13 action, _state = model.predict(obs, deterministic=True)
#      14 obs, reward, done, info = vec_env.step(action)
# ---> 15 vec_env.render()
#      16 # VecEnv resets automatically
#      17 # if done:
#      18 #   obs = vec_env.reset()
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:109, in DummyVecEnv.render(self, mode)
#     102 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#     103     """
#     104     Gym environment rendering. If there are multiple environments then
#     105     they are tiled together in one image via ``BaseVecEnv.render()``.
#     106
#     107     :param mode: The rendering type.
#     108     """
# --> 109     return super().render(mode=mode)
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:215, in VecEnv.render(self, mode)
#     211 # mode == self.render_mode == "human"
#     212 # In that case, we try to call `self.env.render()` but it might
#     213 # crash for subprocesses
#     214 if self.render_mode == "human":
# --> 215     self.env_method("render")
#     216     return
#     218 if mode == "rgb_array" or mode == "human":
#     219     # call the render method of the environments
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:135, in DummyVecEnv.env_method(self, method_name, indices, *method_args, **method_kwargs)
#     133 """Call instance methods of vectorized environments."""
#     134 target_envs = self._get_target_envs(indices)
# --> 135 return [getattr(env_i, method_name)(*method_args, **method_kwargs) for env_i in target_envs]
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:135, in <listcomp>(.0)
#     133 """Call instance methods of vectorized environments."""
#     134 target_envs = self._get_target_envs(indices)
# --> 135 return [getattr(env_i, method_name)(*method_args, **method_kwargs) for env_i in target_envs]
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/core.py:418, in Wrapper.render(self)
#     416 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     417     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 418     return self.env.render()
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/core.py:418, in Wrapper.render(self)
#     416 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     417     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 418     return self.env.render()
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:65, in PassiveEnvChecker.render(self, *args, **kwargs)
#      63     return env_render_passive_checker(self.env, *args, **kwargs)
#      64 else:
# ---> 65     return self.env.render(*args, **kwargs)
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:302, in CartPoleEnv.render(self)
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
# --> 302     self.clock.tick(self.metadata["render_fps"])
#     303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
