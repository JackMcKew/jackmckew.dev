# %%
# # https://github.com/DLR-RM/stable-baselines3/pull/780
# !pip install gymnasium
# !pip install 'gymnasium[mujoco]'
# !pip install matplotlib
# !pip3 install torch torchvision torchaudio
# !pip install "sb3_contrib>=2.0.0a1" --upgrade

# %%
from stable_baselines3 import TD3
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback
import gymnasium as gym

import os

import numpy as np
import time
timestr = time.strftime("%Y%m%d-%H%M%S")
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self,env_name:str, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, f"{timestr}_{env_name}")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
log_dir = "./tmp/gym/"
os.makedirs(log_dir, exist_ok=True)
env_name = "Ant-v4"
env = gym.make(env_name,render_mode='human')
env = Monitor(env, log_dir)


from stable_baselines3 import PPO
from torch import nn
# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(env_name=env_name,check_freq=1000, log_dir=log_dir)

# Ant-v3:
#   normalize: true
#   n_envs: 1
#   policy: 'MlpPolicy'
#   n_timesteps: !!float 1e7
#   batch_size: 32
#   n_steps: 512
#   gamma: 0.98
#   learning_rate: 1.90609e-05
#   ent_coef: 4.9646e-07
#   clip_range: 0.1
#   n_epochs: 10
#   gae_lambda: 0.8
#   max_grad_norm: 0.6
#   vf_coef: 0.677239
model = PPO("MlpPolicy", env,batch_size=32,n_steps=512,gamma=0.98,learning_rate=1.90609e-05,ent_coef=4.9646e-07,clip_range=0.1,n_epochs=10,gae_lambda=0.8,max_grad_norm=0.6,vf_coef=0.677239)
model.learn(total_timesteps=1e7,callback=callback)
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -14.55
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 2000
# Best mean reward: -14.55 - Last mean reward per episode: -198.07
# Num timesteps: 3000
# Best mean reward: -14.55 - Last mean reward per episode: -120.43
# Num timesteps: 4000
# Best mean reward: -14.55 - Last mean reward per episode: -98.88
# Num timesteps: 5000
# Best mean reward: -14.55 - Last mean reward per episode: -86.56
# Num timesteps: 6000
# Best mean reward: -14.55 - Last mean reward per episode: -104.01
# Num timesteps: 7000
# Best mean reward: -14.55 - Last mean reward per episode: -112.26
# Num timesteps: 8000
# Best mean reward: -14.55 - Last mean reward per episode: -103.50
# Num timesteps: 9000
# Best mean reward: -14.55 - Last mean reward per episode: -113.41
# Num timesteps: 10000
# Best mean reward: -14.55 - Last mean reward per episode: -119.85
# Num timesteps: 11000
# Best mean reward: -14.55 - Last mean reward per episode: -111.31
# Num timesteps: 12000
# Best mean reward: -14.55 - Last mean reward per episode: -102.30
# Num timesteps: 13000
# Best mean reward: -14.55 - Last mean reward per episode: -101.23
# Num timesteps: 14000
# Best mean reward: -14.55 - Last mean reward per episode: -108.67
# Num timesteps: 15000
# Best mean reward: -14.55 - Last mean reward per episode: -110.04
# Num timesteps: 16000
# Best mean reward: -14.55 - Last mean reward per episode: -120.24
# Num timesteps: 17000
# Best mean reward: -14.55 - Last mean reward per episode: -130.39
# Num timesteps: 18000
# Best mean reward: -14.55 - Last mean reward per episode: -139.97
# Num timesteps: 19000
# Best mean reward: -14.55 - Last mean reward per episode: -118.48
# Num timesteps: 20000
# Best mean reward: -14.55 - Last mean reward per episode: -125.01
# Num timesteps: 21000
# Best mean reward: -14.55 - Last mean reward per episode: -124.21
# Num timesteps: 22000
# Best mean reward: -14.55 - Last mean reward per episode: -115.92
# Num timesteps: 23000
# Best mean reward: -14.55 - Last mean reward per episode: -126.24
# Num timesteps: 24000
# Best mean reward: -14.55 - Last mean reward per episode: -123.17
# Num timesteps: 25000
# Best mean reward: -14.55 - Last mean reward per episode: -124.41
# Num timesteps: 26000
# Best mean reward: -14.55 - Last mean reward per episode: -138.61
# Num timesteps: 27000
# Best mean reward: -14.55 - Last mean reward per episode: -148.46
# Num timesteps: 28000
# Best mean reward: -14.55 - Last mean reward per episode: -158.65
# Num timesteps: 29000
# Best mean reward: -14.55 - Last mean reward per episode: -149.32
# Num timesteps: 30000
# Best mean reward: -14.55 - Last mean reward per episode: -156.47
# Num timesteps: 31000
# Best mean reward: -14.55 - Last mean reward per episode: -163.23
# Num timesteps: 32000
# Best mean reward: -14.55 - Last mean reward per episode: -162.31
# Num timesteps: 33000
# Best mean reward: -14.55 - Last mean reward per episode: -151.21
# Num timesteps: 34000
# Best mean reward: -14.55 - Last mean reward per episode: -149.87
# Num timesteps: 35000
# Best mean reward: -14.55 - Last mean reward per episode: -151.63
# Num timesteps: 36000
# Best mean reward: -14.55 - Last mean reward per episode: -151.20
# Num timesteps: 37000
# Best mean reward: -14.55 - Last mean reward per episode: -152.34
# Num timesteps: 38000
# Best mean reward: -14.55 - Last mean reward per episode: -154.03
# Num timesteps: 39000
# Best mean reward: -14.55 - Last mean reward per episode: -145.15
# Num timesteps: 40000
# Best mean reward: -14.55 - Last mean reward per episode: -142.28
# Num timesteps: 41000
# Best mean reward: -14.55 - Last mean reward per episode: -151.72
# Num timesteps: 42000
# Best mean reward: -14.55 - Last mean reward per episode: -159.33
# Num timesteps: 43000
# Best mean reward: -14.55 - Last mean reward per episode: -121.54
# Num timesteps: 44000
# Best mean reward: -14.55 - Last mean reward per episode: -115.83
# Num timesteps: 45000
# Best mean reward: -14.55 - Last mean reward per episode: -113.41
# Num timesteps: 46000
# Best mean reward: -14.55 - Last mean reward per episode: -97.26
# Num timesteps: 47000
# Best mean reward: -14.55 - Last mean reward per episode: -105.39
# Num timesteps: 48000
# Best mean reward: -14.55 - Last mean reward per episode: -82.10
# Num timesteps: 49000
# Best mean reward: -14.55 - Last mean reward per episode: -94.01
# Num timesteps: 50000
# Best mean reward: -14.55 - Last mean reward per episode: -73.58
# Num timesteps: 51000
# Best mean reward: -14.55 - Last mean reward per episode: -83.12
# Num timesteps: 52000
# Best mean reward: -14.55 - Last mean reward per episode: -82.59
# Num timesteps: 53000
# Best mean reward: -14.55 - Last mean reward per episode: -70.80
# Num timesteps: 54000
# Best mean reward: -14.55 - Last mean reward per episode: -69.62
# Num timesteps: 55000
# Best mean reward: -14.55 - Last mean reward per episode: -67.46
# Num timesteps: 56000
# Best mean reward: -14.55 - Last mean reward per episode: -77.52
# Num timesteps: 57000
# Best mean reward: -14.55 - Last mean reward per episode: -68.06
# Num timesteps: 58000
# Best mean reward: -14.55 - Last mean reward per episode: -73.32
# Num timesteps: 59000
# Best mean reward: -14.55 - Last mean reward per episode: -66.11
# Num timesteps: 60000
# Best mean reward: -14.55 - Last mean reward per episode: -64.99
# Num timesteps: 61000
# Best mean reward: -14.55 - Last mean reward per episode: -75.16
# Num timesteps: 62000
# Best mean reward: -14.55 - Last mean reward per episode: -70.60
# Num timesteps: 63000
# Best mean reward: -14.55 - Last mean reward per episode: -70.70
# Num timesteps: 64000
# Best mean reward: -14.55 - Last mean reward per episode: -71.16
# Num timesteps: 65000
# Best mean reward: -14.55 - Last mean reward per episode: -69.27
# Num timesteps: 66000
# Best mean reward: -14.55 - Last mean reward per episode: -78.00
# Num timesteps: 67000
# Best mean reward: -14.55 - Last mean reward per episode: -88.07
# Num timesteps: 68000
# Best mean reward: -14.55 - Last mean reward per episode: -89.56
# Num timesteps: 69000
# Best mean reward: -14.55 - Last mean reward per episode: -97.05
# Num timesteps: 70000
# Best mean reward: -14.55 - Last mean reward per episode: -106.47
# Num timesteps: 71000
# Best mean reward: -14.55 - Last mean reward per episode: -111.94
# Num timesteps: 72000
# Best mean reward: -14.55 - Last mean reward per episode: -104.01
# Num timesteps: 73000
# Best mean reward: -14.55 - Last mean reward per episode: -113.17
# Num timesteps: 74000
# Best mean reward: -14.55 - Last mean reward per episode: -101.97
# Num timesteps: 75000
# Best mean reward: -14.55 - Last mean reward per episode: -110.99
# Num timesteps: 76000
# Best mean reward: -14.55 - Last mean reward per episode: -110.42
# Num timesteps: 77000
# Best mean reward: -14.55 - Last mean reward per episode: -112.75
# Num timesteps: 78000
# Best mean reward: -14.55 - Last mean reward per episode: -112.12
# Num timesteps: 79000
# Best mean reward: -14.55 - Last mean reward per episode: -106.31
# Num timesteps: 80000
# Best mean reward: -14.55 - Last mean reward per episode: -106.20
# Num timesteps: 81000
# Best mean reward: -14.55 - Last mean reward per episode: -95.59
# Num timesteps: 82000
# Best mean reward: -14.55 - Last mean reward per episode: -96.62
# Num timesteps: 83000
# Best mean reward: -14.55 - Last mean reward per episode: -94.88
# Num timesteps: 84000
# Best mean reward: -14.55 - Last mean reward per episode: -104.49
# Num timesteps: 85000
# Best mean reward: -14.55 - Last mean reward per episode: -112.02
# Num timesteps: 86000
# Best mean reward: -14.55 - Last mean reward per episode: -111.91
# Num timesteps: 87000
# Best mean reward: -14.55 - Last mean reward per episode: -114.23
# Num timesteps: 88000
# Best mean reward: -14.55 - Last mean reward per episode: -103.35
# Num timesteps: 89000
# Best mean reward: -14.55 - Last mean reward per episode: -95.47
# Num timesteps: 90000
# Best mean reward: -14.55 - Last mean reward per episode: -103.64
# Num timesteps: 91000
# Best mean reward: -14.55 - Last mean reward per episode: -111.68
# Num timesteps: 92000
# Best mean reward: -14.55 - Last mean reward per episode: -104.98
# Num timesteps: 93000
# Best mean reward: -14.55 - Last mean reward per episode: -105.11
# Num timesteps: 94000
# Best mean reward: -14.55 - Last mean reward per episode: -104.28
# Num timesteps: 95000
# Best mean reward: -14.55 - Last mean reward per episode: -107.70
# Num timesteps: 96000
# Best mean reward: -14.55 - Last mean reward per episode: -100.16
# Num timesteps: 97000
# Best mean reward: -14.55 - Last mean reward per episode: -87.72
# Num timesteps: 98000
# Best mean reward: -14.55 - Last mean reward per episode: -76.34
# Num timesteps: 99000
# Best mean reward: -14.55 - Last mean reward per episode: -61.43
# Num timesteps: 100000
# Best mean reward: -14.55 - Last mean reward per episode: -61.31
# Num timesteps: 101000
# Best mean reward: -14.55 - Last mean reward per episode: -69.92
# Num timesteps: 102000
# Best mean reward: -14.55 - Last mean reward per episode: -71.93
# Num timesteps: 103000
# Best mean reward: -14.55 - Last mean reward per episode: -60.49
# Num timesteps: 104000
# Best mean reward: -14.55 - Last mean reward per episode: -63.06
# Num timesteps: 105000
# Best mean reward: -14.55 - Last mean reward per episode: -64.74
# Num timesteps: 106000
# Best mean reward: -14.55 - Last mean reward per episode: -66.60
# Num timesteps: 107000
# Best mean reward: -14.55 - Last mean reward per episode: -48.94
# Num timesteps: 108000
# Best mean reward: -14.55 - Last mean reward per episode: -48.70
# Num timesteps: 109000
# Best mean reward: -14.55 - Last mean reward per episode: -56.53
# Num timesteps: 110000
# Best mean reward: -14.55 - Last mean reward per episode: -54.08
# Num timesteps: 111000
# Best mean reward: -14.55 - Last mean reward per episode: -64.11
# Num timesteps: 112000
# Best mean reward: -14.55 - Last mean reward per episode: -59.65
# Num timesteps: 113000
# Best mean reward: -14.55 - Last mean reward per episode: -68.83
# Num timesteps: 114000
# Best mean reward: -14.55 - Last mean reward per episode: -71.02
# Num timesteps: 115000
# Best mean reward: -14.55 - Last mean reward per episode: -68.67
# Num timesteps: 116000
# Best mean reward: -14.55 - Last mean reward per episode: -76.79
# Num timesteps: 117000
# Best mean reward: -14.55 - Last mean reward per episode: -76.85
# Num timesteps: 118000
# Best mean reward: -14.55 - Last mean reward per episode: -83.72
# Num timesteps: 119000
# Best mean reward: -14.55 - Last mean reward per episode: -76.83
# Num timesteps: 120000
# Best mean reward: -14.55 - Last mean reward per episode: -84.52
# Num timesteps: 121000
# Best mean reward: -14.55 - Last mean reward per episode: -84.55
# Num timesteps: 122000
# Best mean reward: -14.55 - Last mean reward per episode: -89.50
# Num timesteps: 123000
# Best mean reward: -14.55 - Last mean reward per episode: -88.94
# Num timesteps: 124000
# Best mean reward: -14.55 - Last mean reward per episode: -89.28
# Num timesteps: 125000
# Best mean reward: -14.55 - Last mean reward per episode: -89.37
# Num timesteps: 126000
# Best mean reward: -14.55 - Last mean reward per episode: -88.61
# Num timesteps: 127000
# Best mean reward: -14.55 - Last mean reward per episode: -95.48
# Num timesteps: 128000
# Best mean reward: -14.55 - Last mean reward per episode: -94.13
# Num timesteps: 129000
# Best mean reward: -14.55 - Last mean reward per episode: -85.77
# Num timesteps: 130000
# Best mean reward: -14.55 - Last mean reward per episode: -72.85
# Num timesteps: 131000
# Best mean reward: -14.55 - Last mean reward per episode: -65.50
# Num timesteps: 132000
# Best mean reward: -14.55 - Last mean reward per episode: -67.60
# Num timesteps: 133000
# Best mean reward: -14.55 - Last mean reward per episode: -74.28
# Num timesteps: 134000
# Best mean reward: -14.55 - Last mean reward per episode: -77.38
# Num timesteps: 135000
# Best mean reward: -14.55 - Last mean reward per episode: -75.49
# Num timesteps: 136000
# Best mean reward: -14.55 - Last mean reward per episode: -82.45
# Num timesteps: 137000
# Best mean reward: -14.55 - Last mean reward per episode: -70.77
# Num timesteps: 138000
# Best mean reward: -14.55 - Last mean reward per episode: -69.80
# Num timesteps: 139000
# Best mean reward: -14.55 - Last mean reward per episode: -51.90
# Num timesteps: 140000
# Best mean reward: -14.55 - Last mean reward per episode: -43.63
# Num timesteps: 141000
# Best mean reward: -14.55 - Last mean reward per episode: -50.27
# Num timesteps: 142000
# Best mean reward: -14.55 - Last mean reward per episode: -50.11
# Num timesteps: 143000
# Best mean reward: -14.55 - Last mean reward per episode: -53.43
# Num timesteps: 144000
# Best mean reward: -14.55 - Last mean reward per episode: -58.17
# Num timesteps: 145000
# Best mean reward: -14.55 - Last mean reward per episode: -59.51
# Num timesteps: 146000
# Best mean reward: -14.55 - Last mean reward per episode: -67.05
# Num timesteps: 147000
# Best mean reward: -14.55 - Last mean reward per episode: -74.70
# Num timesteps: 148000
# Best mean reward: -14.55 - Last mean reward per episode: -74.75
# Num timesteps: 149000
# Best mean reward: -14.55 - Last mean reward per episode: -81.93
# Num timesteps: 150000
# Best mean reward: -14.55 - Last mean reward per episode: -72.80
# Num timesteps: 151000
# Best mean reward: -14.55 - Last mean reward per episode: -74.18
# Num timesteps: 152000
# Best mean reward: -14.55 - Last mean reward per episode: -69.87
# Num timesteps: 153000
# Best mean reward: -14.55 - Last mean reward per episode: -65.43
# Num timesteps: 154000
# Best mean reward: -14.55 - Last mean reward per episode: -61.77
# Num timesteps: 155000
# Best mean reward: -14.55 - Last mean reward per episode: -61.55
# Num timesteps: 156000
# Best mean reward: -14.55 - Last mean reward per episode: -61.94
# Num timesteps: 157000
# Best mean reward: -14.55 - Last mean reward per episode: -62.26
# Num timesteps: 158000
# Best mean reward: -14.55 - Last mean reward per episode: -63.46
# Num timesteps: 159000
# Best mean reward: -14.55 - Last mean reward per episode: -57.01
# Num timesteps: 160000
# Best mean reward: -14.55 - Last mean reward per episode: -55.46
# Num timesteps: 161000
# Best mean reward: -14.55 - Last mean reward per episode: -61.57
# Num timesteps: 162000
# Best mean reward: -14.55 - Last mean reward per episode: -63.13
# Num timesteps: 163000
# Best mean reward: -14.55 - Last mean reward per episode: -66.18
# Num timesteps: 164000
# Best mean reward: -14.55 - Last mean reward per episode: -56.47
# Num timesteps: 165000
# Best mean reward: -14.55 - Last mean reward per episode: -63.66
# Num timesteps: 166000
# Best mean reward: -14.55 - Last mean reward per episode: -70.69
# Num timesteps: 167000
# Best mean reward: -14.55 - Last mean reward per episode: -68.93
# Num timesteps: 168000
# Best mean reward: -14.55 - Last mean reward per episode: -75.31
# Num timesteps: 169000
# Best mean reward: -14.55 - Last mean reward per episode: -75.96
# Num timesteps: 170000
# Best mean reward: -14.55 - Last mean reward per episode: -81.73
# Num timesteps: 171000
# Best mean reward: -14.55 - Last mean reward per episode: -88.98
# Num timesteps: 172000
# Best mean reward: -14.55 - Last mean reward per episode: -89.94
# Num timesteps: 173000
# Best mean reward: -14.55 - Last mean reward per episode: -89.30
# Num timesteps: 174000
# Best mean reward: -14.55 - Last mean reward per episode: -81.54
# Num timesteps: 175000
# Best mean reward: -14.55 - Last mean reward per episode: -84.53
# Num timesteps: 176000
# Best mean reward: -14.55 - Last mean reward per episode: -92.91
# Num timesteps: 177000
# Best mean reward: -14.55 - Last mean reward per episode: -78.78
# Num timesteps: 178000
# Best mean reward: -14.55 - Last mean reward per episode: -85.23
# Num timesteps: 179000
# Best mean reward: -14.55 - Last mean reward per episode: -85.11
# Num timesteps: 180000
# Best mean reward: -14.55 - Last mean reward per episode: -90.86
# Num timesteps: 181000
# Best mean reward: -14.55 - Last mean reward per episode: -76.37
# Num timesteps: 182000
# Best mean reward: -14.55 - Last mean reward per episode: -75.43
# Num timesteps: 183000
# Best mean reward: -14.55 - Last mean reward per episode: -66.44
# Num timesteps: 184000
# Best mean reward: -14.55 - Last mean reward per episode: -73.46
# Num timesteps: 185000
# Best mean reward: -14.55 - Last mean reward per episode: -79.74
# Num timesteps: 186000
# Best mean reward: -14.55 - Last mean reward per episode: -84.73
# Num timesteps: 187000
# Best mean reward: -14.55 - Last mean reward per episode: -90.21
# Num timesteps: 188000
# Best mean reward: -14.55 - Last mean reward per episode: -83.88
# Num timesteps: 189000
# Best mean reward: -14.55 - Last mean reward per episode: -88.99
# Num timesteps: 190000
# Best mean reward: -14.55 - Last mean reward per episode: -96.26
# Num timesteps: 191000
# Best mean reward: -14.55 - Last mean reward per episode: -84.95
# Num timesteps: 192000
# Best mean reward: -14.55 - Last mean reward per episode: -81.22
# Num timesteps: 193000
# Best mean reward: -14.55 - Last mean reward per episode: -81.22
# Num timesteps: 194000
# Best mean reward: -14.55 - Last mean reward per episode: -81.97
# Num timesteps: 195000
# Best mean reward: -14.55 - Last mean reward per episode: -87.51
# Num timesteps: 196000
# Best mean reward: -14.55 - Last mean reward per episode: -94.31
# Num timesteps: 197000
# Best mean reward: -14.55 - Last mean reward per episode: -93.71
# Num timesteps: 198000
# Best mean reward: -14.55 - Last mean reward per episode: -101.38
# Num timesteps: 199000
# Best mean reward: -14.55 - Last mean reward per episode: -89.72
# Num timesteps: 200000
# Best mean reward: -14.55 - Last mean reward per episode: -89.62
# Num timesteps: 201000
# Best mean reward: -14.55 - Last mean reward per episode: -81.90
# Num timesteps: 202000
# Best mean reward: -14.55 - Last mean reward per episode: -81.64
# Num timesteps: 203000
# Best mean reward: -14.55 - Last mean reward per episode: -75.17
# Num timesteps: 204000
# Best mean reward: -14.55 - Last mean reward per episode: -82.03
# Num timesteps: 205000
# Best mean reward: -14.55 - Last mean reward per episode: -83.70
# Num timesteps: 206000
# Best mean reward: -14.55 - Last mean reward per episode: -83.66
# Num timesteps: 207000
# Best mean reward: -14.55 - Last mean reward per episode: -78.97
# Num timesteps: 208000
# Best mean reward: -14.55 - Last mean reward per episode: -65.76
# Num timesteps: 209000
# Best mean reward: -14.55 - Last mean reward per episode: -70.25
# Num timesteps: 210000
# Best mean reward: -14.55 - Last mean reward per episode: -70.86
# Num timesteps: 211000
# Best mean reward: -14.55 - Last mean reward per episode: -61.82
# Num timesteps: 212000
# Best mean reward: -14.55 - Last mean reward per episode: -63.01
# Num timesteps: 213000
# Best mean reward: -14.55 - Last mean reward per episode: -69.25
# Num timesteps: 214000
# Best mean reward: -14.55 - Last mean reward per episode: -69.22
# Num timesteps: 215000
# Best mean reward: -14.55 - Last mean reward per episode: -67.96
# Num timesteps: 216000
# Best mean reward: -14.55 - Last mean reward per episode: -61.78
# Num timesteps: 217000
# Best mean reward: -14.55 - Last mean reward per episode: -60.43
# Num timesteps: 218000
# Best mean reward: -14.55 - Last mean reward per episode: -67.17
# Num timesteps: 219000
# Best mean reward: -14.55 - Last mean reward per episode: -61.68
# Num timesteps: 220000
# Best mean reward: -14.55 - Last mean reward per episode: -63.09
# Num timesteps: 221000
# Best mean reward: -14.55 - Last mean reward per episode: -64.04
# Num timesteps: 222000
# Best mean reward: -14.55 - Last mean reward per episode: -53.26
# Num timesteps: 223000
# Best mean reward: -14.55 - Last mean reward per episode: -50.84
# Num timesteps: 224000
# Best mean reward: -14.55 - Last mean reward per episode: -56.73
# Num timesteps: 225000
# Best mean reward: -14.55 - Last mean reward per episode: -62.34
# Num timesteps: 226000
# Best mean reward: -14.55 - Last mean reward per episode: -60.35
# Num timesteps: 227000
# Best mean reward: -14.55 - Last mean reward per episode: -68.50
# Num timesteps: 228000
# Best mean reward: -14.55 - Last mean reward per episode: -66.34
# Num timesteps: 229000
# Best mean reward: -14.55 - Last mean reward per episode: -65.88
# Num timesteps: 230000
# Best mean reward: -14.55 - Last mean reward per episode: -63.40
# Num timesteps: 231000
# Best mean reward: -14.55 - Last mean reward per episode: -70.42
# Num timesteps: 232000
# Best mean reward: -14.55 - Last mean reward per episode: -71.81
# Num timesteps: 233000
# Best mean reward: -14.55 - Last mean reward per episode: -77.81
# Num timesteps: 234000
# Best mean reward: -14.55 - Last mean reward per episode: -83.55
# Num timesteps: 235000
# Best mean reward: -14.55 - Last mean reward per episode: -88.07
# Num timesteps: 236000
# Best mean reward: -14.55 - Last mean reward per episode: -93.76
# Num timesteps: 237000
# Best mean reward: -14.55 - Last mean reward per episode: -88.94
# Num timesteps: 238000
# Best mean reward: -14.55 - Last mean reward per episode: -92.34
# Num timesteps: 239000
# Best mean reward: -14.55 - Last mean reward per episode: -97.62
# Num timesteps: 240000
# Best mean reward: -14.55 - Last mean reward per episode: -87.15
# Num timesteps: 241000
# Best mean reward: -14.55 - Last mean reward per episode: -80.08
# Num timesteps: 242000
# Best mean reward: -14.55 - Last mean reward per episode: -76.39
# Num timesteps: 243000
# Best mean reward: -14.55 - Last mean reward per episode: -70.81
# Num timesteps: 244000
# Best mean reward: -14.55 - Last mean reward per episode: -70.27
# Num timesteps: 245000
# Best mean reward: -14.55 - Last mean reward per episode: -75.24
# Num timesteps: 246000
# Best mean reward: -14.55 - Last mean reward per episode: -80.82
# Num timesteps: 247000
# Best mean reward: -14.55 - Last mean reward per episode: -86.53
# Num timesteps: 248000
# Best mean reward: -14.55 - Last mean reward per episode: -86.25
# Num timesteps: 249000
# Best mean reward: -14.55 - Last mean reward per episode: -91.77
# Num timesteps: 250000
# Best mean reward: -14.55 - Last mean reward per episode: -96.46
# Num timesteps: 251000
# Best mean reward: -14.55 - Last mean reward per episode: -80.36
# Num timesteps: 252000
# Best mean reward: -14.55 - Last mean reward per episode: -76.91
# Num timesteps: 253000
# Best mean reward: -14.55 - Last mean reward per episode: -77.25
# Num timesteps: 254000
# Best mean reward: -14.55 - Last mean reward per episode: -79.66
# Num timesteps: 255000
# Best mean reward: -14.55 - Last mean reward per episode: -81.88
# Num timesteps: 256000
# Best mean reward: -14.55 - Last mean reward per episode: -81.27
# Num timesteps: 257000
# Best mean reward: -14.55 - Last mean reward per episode: -74.93
# Num timesteps: 258000
# Best mean reward: -14.55 - Last mean reward per episode: -64.53
# Num timesteps: 259000
# Best mean reward: -14.55 - Last mean reward per episode: -65.58
# Num timesteps: 260000
# Best mean reward: -14.55 - Last mean reward per episode: -70.97
# Num timesteps: 261000
# Best mean reward: -14.55 - Last mean reward per episode: -57.58
# Num timesteps: 262000
# Best mean reward: -14.55 - Last mean reward per episode: -62.35
# Num timesteps: 263000
# Best mean reward: -14.55 - Last mean reward per episode: -55.00
# Num timesteps: 264000
# Best mean reward: -14.55 - Last mean reward per episode: -51.14
# Num timesteps: 265000
# Best mean reward: -14.55 - Last mean reward per episode: -49.19
# Num timesteps: 266000
# Best mean reward: -14.55 - Last mean reward per episode: -53.45
# Num timesteps: 267000
# Best mean reward: -14.55 - Last mean reward per episode: -49.11
# Num timesteps: 268000
# Best mean reward: -14.55 - Last mean reward per episode: -54.14
# Num timesteps: 269000
# Best mean reward: -14.55 - Last mean reward per episode: -45.13
# Num timesteps: 270000
# Best mean reward: -14.55 - Last mean reward per episode: -40.33
# Num timesteps: 271000
# Best mean reward: -14.55 - Last mean reward per episode: -47.10
# Num timesteps: 272000
# Best mean reward: -14.55 - Last mean reward per episode: -45.47
# Num timesteps: 273000
# Best mean reward: -14.55 - Last mean reward per episode: -44.11
# Num timesteps: 274000
# Best mean reward: -14.55 - Last mean reward per episode: -49.90
# Num timesteps: 275000
# Best mean reward: -14.55 - Last mean reward per episode: -49.55
# Num timesteps: 276000
# Best mean reward: -14.55 - Last mean reward per episode: -53.62
# Num timesteps: 277000
# Best mean reward: -14.55 - Last mean reward per episode: -53.39
# Num timesteps: 278000
# Best mean reward: -14.55 - Last mean reward per episode: -52.61
# Num timesteps: 279000
# Best mean reward: -14.55 - Last mean reward per episode: -48.57
# Num timesteps: 280000
# Best mean reward: -14.55 - Last mean reward per episode: -48.48
# Num timesteps: 281000
# Best mean reward: -14.55 - Last mean reward per episode: -52.40
# Num timesteps: 282000
# Best mean reward: -14.55 - Last mean reward per episode: -56.91
# Num timesteps: 283000
# Best mean reward: -14.55 - Last mean reward per episode: -51.98
# Num timesteps: 284000
# Best mean reward: -14.55 - Last mean reward per episode: -56.56
# Num timesteps: 285000
# Best mean reward: -14.55 - Last mean reward per episode: -59.12
# Num timesteps: 286000
# Best mean reward: -14.55 - Last mean reward per episode: -58.89
# Num timesteps: 287000
# Best mean reward: -14.55 - Last mean reward per episode: -46.98
# Num timesteps: 288000
# Best mean reward: -14.55 - Last mean reward per episode: -41.76
# Num timesteps: 289000
# Best mean reward: -14.55 - Last mean reward per episode: -46.91
# Num timesteps: 290000
# Best mean reward: -14.55 - Last mean reward per episode: -43.77
# Num timesteps: 291000
# Best mean reward: -14.55 - Last mean reward per episode: -46.95
# Num timesteps: 292000
# Best mean reward: -14.55 - Last mean reward per episode: -43.42
# Num timesteps: 293000
# Best mean reward: -14.55 - Last mean reward per episode: -47.72
# Num timesteps: 294000
# Best mean reward: -14.55 - Last mean reward per episode: -44.84
# Num timesteps: 295000
# Best mean reward: -14.55 - Last mean reward per episode: -49.41
# Num timesteps: 296000
# Best mean reward: -14.55 - Last mean reward per episode: -46.19
# Num timesteps: 297000
# Best mean reward: -14.55 - Last mean reward per episode: -46.38
# Num timesteps: 298000
# Best mean reward: -14.55 - Last mean reward per episode: -47.15
# Num timesteps: 299000
# Best mean reward: -14.55 - Last mean reward per episode: -52.84
# Num timesteps: 300000
# Best mean reward: -14.55 - Last mean reward per episode: -52.68
# Num timesteps: 301000
# Best mean reward: -14.55 - Last mean reward per episode: -52.07
# Num timesteps: 302000
# Best mean reward: -14.55 - Last mean reward per episode: -55.72
# Num timesteps: 303000
# Best mean reward: -14.55 - Last mean reward per episode: -59.98
# Num timesteps: 304000
# Best mean reward: -14.55 - Last mean reward per episode: -53.06
# Num timesteps: 305000
# Best mean reward: -14.55 - Last mean reward per episode: -56.05
# Num timesteps: 306000
# Best mean reward: -14.55 - Last mean reward per episode: -54.85
# Num timesteps: 307000
# Best mean reward: -14.55 - Last mean reward per episode: -59.73
# Num timesteps: 308000
# Best mean reward: -14.55 - Last mean reward per episode: -62.71
# Num timesteps: 309000
# Best mean reward: -14.55 - Last mean reward per episode: -56.67
# Num timesteps: 310000
# Best mean reward: -14.55 - Last mean reward per episode: -62.23
# Num timesteps: 311000
# Best mean reward: -14.55 - Last mean reward per episode: -63.70
# Num timesteps: 312000
# Best mean reward: -14.55 - Last mean reward per episode: -62.56
# Num timesteps: 313000
# Best mean reward: -14.55 - Last mean reward per episode: -58.98
# Num timesteps: 314000
# Best mean reward: -14.55 - Last mean reward per episode: -49.29
# Num timesteps: 315000
# Best mean reward: -14.55 - Last mean reward per episode: -53.96
# Num timesteps: 316000
# Best mean reward: -14.55 - Last mean reward per episode: -54.15
# Num timesteps: 317000
# Best mean reward: -14.55 - Last mean reward per episode: -51.79
# Num timesteps: 318000
# Best mean reward: -14.55 - Last mean reward per episode: -39.60
# Num timesteps: 319000
# Best mean reward: -14.55 - Last mean reward per episode: -38.43
# Num timesteps: 320000
# Best mean reward: -14.55 - Last mean reward per episode: -31.79
# Num timesteps: 321000
# Best mean reward: -14.55 - Last mean reward per episode: -33.50
# Num timesteps: 322000
# Best mean reward: -14.55 - Last mean reward per episode: -33.24
# Num timesteps: 323000
# Best mean reward: -14.55 - Last mean reward per episode: -39.60
# Num timesteps: 324000
# Best mean reward: -14.55 - Last mean reward per episode: -39.54
# Num timesteps: 325000
# Best mean reward: -14.55 - Last mean reward per episode: -43.21
# Num timesteps: 326000
# Best mean reward: -14.55 - Last mean reward per episode: -40.95
# Num timesteps: 327000
# Best mean reward: -14.55 - Last mean reward per episode: -41.28
# Num timesteps: 328000
# Best mean reward: -14.55 - Last mean reward per episode: -41.19
# Num timesteps: 329000
# Best mean reward: -14.55 - Last mean reward per episode: -40.06
# Num timesteps: 330000
# Best mean reward: -14.55 - Last mean reward per episode: -41.99
# Num timesteps: 331000
# Best mean reward: -14.55 - Last mean reward per episode: -46.14
# Num timesteps: 332000
# Best mean reward: -14.55 - Last mean reward per episode: -51.07
# Num timesteps: 333000
# Best mean reward: -14.55 - Last mean reward per episode: -50.76
# Num timesteps: 334000
# Best mean reward: -14.55 - Last mean reward per episode: -48.00
# Num timesteps: 335000
# Best mean reward: -14.55 - Last mean reward per episode: -46.12
# Num timesteps: 336000
# Best mean reward: -14.55 - Last mean reward per episode: -50.19
# Num timesteps: 337000
# Best mean reward: -14.55 - Last mean reward per episode: -49.02
# Num timesteps: 338000
# Best mean reward: -14.55 - Last mean reward per episode: -49.67
# Num timesteps: 339000
# Best mean reward: -14.55 - Last mean reward per episode: -46.34
# Num timesteps: 340000
# Best mean reward: -14.55 - Last mean reward per episode: -46.85
# Num timesteps: 341000
# Best mean reward: -14.55 - Last mean reward per episode: -50.37
# Num timesteps: 342000
# Best mean reward: -14.55 - Last mean reward per episode: -50.30
# Num timesteps: 343000
# Best mean reward: -14.55 - Last mean reward per episode: -51.42
# Num timesteps: 344000
# Best mean reward: -14.55 - Last mean reward per episode: -42.89
# Num timesteps: 345000
# Best mean reward: -14.55 - Last mean reward per episode: -43.91
# Num timesteps: 346000
# Best mean reward: -14.55 - Last mean reward per episode: -40.40
# Num timesteps: 347000
# Best mean reward: -14.55 - Last mean reward per episode: -43.51
# Num timesteps: 348000
# Best mean reward: -14.55 - Last mean reward per episode: -32.39
# Num timesteps: 349000
# Best mean reward: -14.55 - Last mean reward per episode: -30.38
# Num timesteps: 350000
# Best mean reward: -14.55 - Last mean reward per episode: -32.99
# Num timesteps: 351000
# Best mean reward: -14.55 - Last mean reward per episode: -36.23
# Num timesteps: 352000
# Best mean reward: -14.55 - Last mean reward per episode: -34.17
# Num timesteps: 353000
# Best mean reward: -14.55 - Last mean reward per episode: -33.61
# Num timesteps: 354000
# Best mean reward: -14.55 - Last mean reward per episode: -35.02
# Num timesteps: 355000
# Best mean reward: -14.55 - Last mean reward per episode: -33.69
# Num timesteps: 356000
# Best mean reward: -14.55 - Last mean reward per episode: -29.12
# Num timesteps: 357000
# Best mean reward: -14.55 - Last mean reward per episode: -29.31
# Num timesteps: 358000
# Best mean reward: -14.55 - Last mean reward per episode: -32.06
# Num timesteps: 359000
# Best mean reward: -14.55 - Last mean reward per episode: -34.04
# Num timesteps: 360000
# Best mean reward: -14.55 - Last mean reward per episode: -35.90
# Num timesteps: 361000
# Best mean reward: -14.55 - Last mean reward per episode: -35.11
# Num timesteps: 362000
# Best mean reward: -14.55 - Last mean reward per episode: -28.57
# Num timesteps: 363000
# Best mean reward: -14.55 - Last mean reward per episode: -31.80
# Num timesteps: 364000
# Best mean reward: -14.55 - Last mean reward per episode: -33.05
# Num timesteps: 365000
# Best mean reward: -14.55 - Last mean reward per episode: -30.72
# Num timesteps: 366000
# Best mean reward: -14.55 - Last mean reward per episode: -33.91
# Num timesteps: 367000
# Best mean reward: -14.55 - Last mean reward per episode: -34.85
# Num timesteps: 368000
# Best mean reward: -14.55 - Last mean reward per episode: -37.76
# Num timesteps: 369000
# Best mean reward: -14.55 - Last mean reward per episode: -37.16
# Num timesteps: 370000
# Best mean reward: -14.55 - Last mean reward per episode: -38.33
# Num timesteps: 371000
# Best mean reward: -14.55 - Last mean reward per episode: -42.13
# Num timesteps: 372000
# Best mean reward: -14.55 - Last mean reward per episode: -43.87
# Num timesteps: 373000
# Best mean reward: -14.55 - Last mean reward per episode: -44.42
# Num timesteps: 374000
# Best mean reward: -14.55 - Last mean reward per episode: -43.08
# Num timesteps: 375000
# Best mean reward: -14.55 - Last mean reward per episode: -43.45
# Num timesteps: 376000
# Best mean reward: -14.55 - Last mean reward per episode: -47.02
# Num timesteps: 377000
# Best mean reward: -14.55 - Last mean reward per episode: -48.18
# Num timesteps: 378000
# Best mean reward: -14.55 - Last mean reward per episode: -49.90
# Num timesteps: 379000
# Best mean reward: -14.55 - Last mean reward per episode: -52.01
# Num timesteps: 380000
# Best mean reward: -14.55 - Last mean reward per episode: -43.00
# Num timesteps: 381000
# Best mean reward: -14.55 - Last mean reward per episode: -42.97
# Num timesteps: 382000
# Best mean reward: -14.55 - Last mean reward per episode: -38.45
# Num timesteps: 383000
# Best mean reward: -14.55 - Last mean reward per episode: -41.18
# Num timesteps: 384000
# Best mean reward: -14.55 - Last mean reward per episode: -36.76
# Num timesteps: 385000
# Best mean reward: -14.55 - Last mean reward per episode: -36.42
# Num timesteps: 386000
# Best mean reward: -14.55 - Last mean reward per episode: -35.86
# Num timesteps: 387000
# Best mean reward: -14.55 - Last mean reward per episode: -33.75
# Num timesteps: 388000
# Best mean reward: -14.55 - Last mean reward per episode: -30.20
# Num timesteps: 389000
# Best mean reward: -14.55 - Last mean reward per episode: -28.39
# Num timesteps: 390000
# Best mean reward: -14.55 - Last mean reward per episode: -30.35
# Num timesteps: 391000
# Best mean reward: -14.55 - Last mean reward per episode: -28.98
# Num timesteps: 392000
# Best mean reward: -14.55 - Last mean reward per episode: -31.27
# Num timesteps: 393000
# Best mean reward: -14.55 - Last mean reward per episode: -32.72
# Num timesteps: 394000
# Best mean reward: -14.55 - Last mean reward per episode: -33.92
# Num timesteps: 395000
# Best mean reward: -14.55 - Last mean reward per episode: -35.75
# Num timesteps: 396000
# Best mean reward: -14.55 - Last mean reward per episode: -35.91
# Num timesteps: 397000
# Best mean reward: -14.55 - Last mean reward per episode: -35.65
# Num timesteps: 398000
# Best mean reward: -14.55 - Last mean reward per episode: -37.28
# Num timesteps: 399000
# Best mean reward: -14.55 - Last mean reward per episode: -32.55
# Num timesteps: 400000
# Best mean reward: -14.55 - Last mean reward per episode: -32.18
# Num timesteps: 401000
# Best mean reward: -14.55 - Last mean reward per episode: -30.21
# Num timesteps: 402000
# Best mean reward: -14.55 - Last mean reward per episode: -30.06
# Num timesteps: 403000
# Best mean reward: -14.55 - Last mean reward per episode: -27.66
# Num timesteps: 404000
# Best mean reward: -14.55 - Last mean reward per episode: -29.97
# Num timesteps: 405000
# Best mean reward: -14.55 - Last mean reward per episode: -28.83
# Num timesteps: 406000
# Best mean reward: -14.55 - Last mean reward per episode: -29.16
# Num timesteps: 407000
# Best mean reward: -14.55 - Last mean reward per episode: -19.21
# Num timesteps: 408000
# Best mean reward: -14.55 - Last mean reward per episode: -20.97
# Num timesteps: 409000
# Best mean reward: -14.55 - Last mean reward per episode: -18.49
# Num timesteps: 410000
# Best mean reward: -14.55 - Last mean reward per episode: -19.91
# Num timesteps: 411000
# Best mean reward: -14.55 - Last mean reward per episode: -19.64
# Num timesteps: 412000
# Best mean reward: -14.55 - Last mean reward per episode: -22.61
# Num timesteps: 413000
# Best mean reward: -14.55 - Last mean reward per episode: -24.22
# Num timesteps: 414000
# Best mean reward: -14.55 - Last mean reward per episode: -23.20
# Num timesteps: 415000
# Best mean reward: -14.55 - Last mean reward per episode: -22.23
# Num timesteps: 416000
# Best mean reward: -14.55 - Last mean reward per episode: -20.38
# Num timesteps: 417000
# Best mean reward: -14.55 - Last mean reward per episode: -18.78
# Num timesteps: 418000
# Best mean reward: -14.55 - Last mean reward per episode: -20.16
# Num timesteps: 419000
# Best mean reward: -14.55 - Last mean reward per episode: -19.10
# Num timesteps: 420000
# Best mean reward: -14.55 - Last mean reward per episode: -19.91
# Num timesteps: 421000
# Best mean reward: -14.55 - Last mean reward per episode: -21.66
# Num timesteps: 422000
# Best mean reward: -14.55 - Last mean reward per episode: -19.35
# Num timesteps: 423000
# Best mean reward: -14.55 - Last mean reward per episode: -20.15
# Num timesteps: 424000
# Best mean reward: -14.55 - Last mean reward per episode: -21.75
# Num timesteps: 425000
# Best mean reward: -14.55 - Last mean reward per episode: -21.00
# Num timesteps: 426000
# Best mean reward: -14.55 - Last mean reward per episode: -21.74
# Num timesteps: 427000
# Best mean reward: -14.55 - Last mean reward per episode: -21.92
# Num timesteps: 428000
# Best mean reward: -14.55 - Last mean reward per episode: -23.26
# Num timesteps: 429000
# Best mean reward: -14.55 - Last mean reward per episode: -23.48
# Num timesteps: 430000
# Best mean reward: -14.55 - Last mean reward per episode: -24.32
# Num timesteps: 431000
# Best mean reward: -14.55 - Last mean reward per episode: -24.70
# Num timesteps: 432000
# Best mean reward: -14.55 - Last mean reward per episode: -26.98
# Num timesteps: 433000
# Best mean reward: -14.55 - Last mean reward per episode: -28.17
# Num timesteps: 434000
# Best mean reward: -14.55 - Last mean reward per episode: -28.65
# Num timesteps: 435000
# Best mean reward: -14.55 - Last mean reward per episode: -30.38
# Num timesteps: 436000
# Best mean reward: -14.55 - Last mean reward per episode: -31.25
# Num timesteps: 437000
# Best mean reward: -14.55 - Last mean reward per episode: -30.83
# Num timesteps: 438000
# Best mean reward: -14.55 - Last mean reward per episode: -32.98
# Num timesteps: 439000
# Best mean reward: -14.55 - Last mean reward per episode: -31.23
# Num timesteps: 440000
# Best mean reward: -14.55 - Last mean reward per episode: -30.02
# Num timesteps: 441000
# Best mean reward: -14.55 - Last mean reward per episode: -27.49
# Num timesteps: 442000
# Best mean reward: -14.55 - Last mean reward per episode: -27.35
# Num timesteps: 443000
# Best mean reward: -14.55 - Last mean reward per episode: -26.22
# Num timesteps: 444000
# Best mean reward: -14.55 - Last mean reward per episode: -25.84
# Num timesteps: 445000
# Best mean reward: -14.55 - Last mean reward per episode: -26.08
# Num timesteps: 446000
# Best mean reward: -14.55 - Last mean reward per episode: -26.16
# Num timesteps: 447000
# Best mean reward: -14.55 - Last mean reward per episode: -25.35
# Num timesteps: 448000
# Best mean reward: -14.55 - Last mean reward per episode: -24.06
# Num timesteps: 449000
# Best mean reward: -14.55 - Last mean reward per episode: -19.45
# Num timesteps: 450000
# Best mean reward: -14.55 - Last mean reward per episode: -14.47
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 451000
# Best mean reward: -14.47 - Last mean reward per episode: -15.16
# Num timesteps: 452000
# Best mean reward: -14.47 - Last mean reward per episode: -11.07
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 453000
# Best mean reward: -11.07 - Last mean reward per episode: -9.87
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 454000
# Best mean reward: -9.87 - Last mean reward per episode: -4.83
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 455000
# Best mean reward: -4.83 - Last mean reward per episode: -4.64
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 456000
# Best mean reward: -4.64 - Last mean reward per episode: -4.62
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 457000
# Best mean reward: -4.62 - Last mean reward per episode: -5.63
# Num timesteps: 458000
# Best mean reward: -4.62 - Last mean reward per episode: -5.79
# Num timesteps: 459000
# Best mean reward: -4.62 - Last mean reward per episode: -6.67
# Num timesteps: 460000
# Best mean reward: -4.62 - Last mean reward per episode: -7.00
# Num timesteps: 461000
# Best mean reward: -4.62 - Last mean reward per episode: -6.86
# Num timesteps: 462000
# Best mean reward: -4.62 - Last mean reward per episode: -6.40
# Num timesteps: 463000
# Best mean reward: -4.62 - Last mean reward per episode: -3.78
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 464000
# Best mean reward: -3.78 - Last mean reward per episode: -4.46
# Num timesteps: 465000
# Best mean reward: -3.78 - Last mean reward per episode: -4.76
# Num timesteps: 466000
# Best mean reward: -3.78 - Last mean reward per episode: -3.38
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 467000
# Best mean reward: -3.38 - Last mean reward per episode: -3.56
# Num timesteps: 468000
# Best mean reward: -3.38 - Last mean reward per episode: -3.75
# Num timesteps: 469000
# Best mean reward: -3.38 - Last mean reward per episode: -3.85
# Num timesteps: 470000
# Best mean reward: -3.38 - Last mean reward per episode: -4.30
# Num timesteps: 471000
# Best mean reward: -3.38 - Last mean reward per episode: -3.61
# Num timesteps: 472000
# Best mean reward: -3.38 - Last mean reward per episode: -2.91
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 473000
# Best mean reward: -2.91 - Last mean reward per episode: -3.69
# Num timesteps: 474000
# Best mean reward: -2.91 - Last mean reward per episode: -5.04
# Num timesteps: 475000
# Best mean reward: -2.91 - Last mean reward per episode: -5.27
# Num timesteps: 476000
# Best mean reward: -2.91 - Last mean reward per episode: -5.16
# Num timesteps: 477000
# Best mean reward: -2.91 - Last mean reward per episode: -4.51
# Num timesteps: 478000
# Best mean reward: -2.91 - Last mean reward per episode: -3.56
# Num timesteps: 479000
# Best mean reward: -2.91 - Last mean reward per episode: -3.66
# Num timesteps: 480000
# Best mean reward: -2.91 - Last mean reward per episode: -2.67
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 481000
# Best mean reward: -2.67 - Last mean reward per episode: -1.05
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 482000
# Best mean reward: -1.05 - Last mean reward per episode: 0.62
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 483000
# Best mean reward: 0.62 - Last mean reward per episode: 1.52
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 484000
# Best mean reward: 1.52 - Last mean reward per episode: 0.79
# Num timesteps: 485000
# Best mean reward: 1.52 - Last mean reward per episode: 0.45
# Num timesteps: 486000
# Best mean reward: 1.52 - Last mean reward per episode: 0.24
# Num timesteps: 487000
# Best mean reward: 1.52 - Last mean reward per episode: 0.93
# Num timesteps: 488000
# Best mean reward: 1.52 - Last mean reward per episode: 0.75
# Num timesteps: 489000
# Best mean reward: 1.52 - Last mean reward per episode: 1.33
# Num timesteps: 490000
# Best mean reward: 1.52 - Last mean reward per episode: 2.19
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 491000
# Best mean reward: 2.19 - Last mean reward per episode: 1.62
# Num timesteps: 492000
# Best mean reward: 2.19 - Last mean reward per episode: 2.24
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 493000
# Best mean reward: 2.24 - Last mean reward per episode: 3.06
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 494000
# Best mean reward: 3.06 - Last mean reward per episode: 3.35
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 495000
# Best mean reward: 3.35 - Last mean reward per episode: 3.23
# Num timesteps: 496000
# Best mean reward: 3.35 - Last mean reward per episode: 3.75
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 497000
# Best mean reward: 3.75 - Last mean reward per episode: 4.60
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 498000
# Best mean reward: 4.60 - Last mean reward per episode: 4.94
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 499000
# Best mean reward: 4.94 - Last mean reward per episode: 5.20
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 500000
# Best mean reward: 5.20 - Last mean reward per episode: 5.17
# Num timesteps: 501000
# Best mean reward: 5.20 - Last mean reward per episode: 4.86
# Num timesteps: 502000
# Best mean reward: 5.20 - Last mean reward per episode: 5.88
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 503000
# Best mean reward: 5.88 - Last mean reward per episode: 10.50
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 504000
# Best mean reward: 10.50 - Last mean reward per episode: 11.42
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 505000
# Best mean reward: 11.42 - Last mean reward per episode: 12.66
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 506000
# Best mean reward: 12.66 - Last mean reward per episode: 12.92
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 507000
# Best mean reward: 12.92 - Last mean reward per episode: 13.93
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 508000
# Best mean reward: 13.93 - Last mean reward per episode: 14.84
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 509000
# Best mean reward: 14.84 - Last mean reward per episode: 15.99
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 510000
# Best mean reward: 15.99 - Last mean reward per episode: 16.77
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 511000
# Best mean reward: 16.77 - Last mean reward per episode: 17.03
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 512000
# Best mean reward: 17.03 - Last mean reward per episode: 16.56
# Num timesteps: 513000
# Best mean reward: 17.03 - Last mean reward per episode: 19.31
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 514000
# Best mean reward: 19.31 - Last mean reward per episode: 18.17
# Num timesteps: 515000
# Best mean reward: 19.31 - Last mean reward per episode: 19.09
# Num timesteps: 516000
# Best mean reward: 19.31 - Last mean reward per episode: 19.48
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 517000
# Best mean reward: 19.48 - Last mean reward per episode: 20.83
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 518000
# Best mean reward: 20.83 - Last mean reward per episode: 21.56
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 519000
# Best mean reward: 21.56 - Last mean reward per episode: 25.22
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 520000
# Best mean reward: 25.22 - Last mean reward per episode: 25.32
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 521000
# Best mean reward: 25.32 - Last mean reward per episode: 25.39
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 522000
# Best mean reward: 25.39 - Last mean reward per episode: 26.89
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 523000
# Best mean reward: 26.89 - Last mean reward per episode: 27.48
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 524000
# Best mean reward: 27.48 - Last mean reward per episode: 28.96
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 525000
# Best mean reward: 28.96 - Last mean reward per episode: 28.59
# Num timesteps: 526000
# Best mean reward: 28.96 - Last mean reward per episode: 31.07
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# Num timesteps: 527000
# Best mean reward: 31.07 - Last mean reward per episode: 30.74
# Num timesteps: 528000
# Best mean reward: 31.07 - Last mean reward per episode: 31.06
# Num timesteps: 529000
# Best mean reward: 31.07 - Last mean reward per episode: 33.05
# Saving new best model to ./tmp/gym/20230417-224635_Ant-v4.zip
# ...
# Best mean reward: 4963.22 - Last mean reward per episode: 4849.20
# Num timesteps: 9822000
# Best mean reward: 4963.22 - Last mean reward per episode: 4848.43
# Num timesteps: 9823000
# Best mean reward: 4963.22 - Last mean reward per episode: 4811.25
# Num timesteps: 9824000
# Best mean reward: 4963.22 - Last mean reward per episode: 4811.34
# Num timesteps: 9825000
# Best mean reward: 4963.22 - Last mean reward per episode: 4814.07
# Num timesteps: 9826000
# Best mean reward: 4963.22 - Last mean reward per episode: 4856.91
# Num timesteps: 9827000
# Best mean reward: 4963.22 - Last mean reward per episode: 4832.34
# Num timesteps: 9828000
# Best mean reward: 4963.22 - Last mean reward per episode: 4828.73
# Num timesteps: 9829000
# Best mean reward: 4963.22 - Last mean reward per episode: 4869.40
# Num timesteps: 9830000
# Best mean reward: 4963.22 - Last mean reward per episode: 4846.99
# Num timesteps: 9831000
# Best mean reward: 4963.22 - Last mean reward per episode: 4815.70
# Num timesteps: 9832000
# Best mean reward: 4963.22 - Last mean reward per episode: 4817.79
# Num timesteps: 9833000
# Best mean reward: 4963.22 - Last mean reward per episode: 4814.42
# Num timesteps: 9834000
# Best mean reward: 4963.22 - Last mean reward per episode: 4814.52
# Num timesteps: 9835000
# Best mean reward: 4963.22 - Last mean reward per episode: 4806.04
# Num timesteps: 9836000
# Best mean reward: 4963.22 - Last mean reward per episode: 4824.58
# Num timesteps: 9837000
# Best mean reward: 4963.22 - Last mean reward per episode: 4810.30
# Num timesteps: 9838000
# Best mean reward: 4963.22 - Last mean reward per episode: 4811.33
# Num timesteps: 9839000
# Best mean reward: 4963.22 - Last mean reward per episode: 4807.24
# Num timesteps: 9840000
# Best mean reward: 4963.22 - Last mean reward per episode: 4804.97
# Num timesteps: 9841000
# Best mean reward: 4963.22 - Last mean reward per episode: 4807.81
# Num timesteps: 9842000
# Best mean reward: 4963.22 - Last mean reward per episode: 4808.86
# Num timesteps: 9843000
# Best mean reward: 4963.22 - Last mean reward per episode: 4803.60
# Num timesteps: 9844000
# Best mean reward: 4963.22 - Last mean reward per episode: 4833.99
# Num timesteps: 9845000
# Best mean reward: 4963.22 - Last mean reward per episode: 4828.40
# Num timesteps: 9846000
# Best mean reward: 4963.22 - Last mean reward per episode: 4833.40
# Num timesteps: 9847000
# Best mean reward: 4963.22 - Last mean reward per episode: 4794.22
# Num timesteps: 9848000
# Best mean reward: 4963.22 - Last mean reward per episode: 4792.70
# Num timesteps: 9849000
# Best mean reward: 4963.22 - Last mean reward per episode: 4819.58
# Num timesteps: 9850000
# Best mean reward: 4963.22 - Last mean reward per episode: 4818.47
# Num timesteps: 9851000
# Best mean reward: 4963.22 - Last mean reward per episode: 4731.65
# Num timesteps: 9852000
# Best mean reward: 4963.22 - Last mean reward per episode: 4740.51
# Num timesteps: 9853000
# Best mean reward: 4963.22 - Last mean reward per episode: 4739.38
# Num timesteps: 9854000
# Best mean reward: 4963.22 - Last mean reward per episode: 4735.90
# Num timesteps: 9855000
# Best mean reward: 4963.22 - Last mean reward per episode: 4749.69
# Num timesteps: 9856000
# Best mean reward: 4963.22 - Last mean reward per episode: 4748.03
# Num timesteps: 9857000
# Best mean reward: 4963.22 - Last mean reward per episode: 4745.10
# Num timesteps: 9858000
# Best mean reward: 4963.22 - Last mean reward per episode: 4739.60
# Num timesteps: 9859000
# Best mean reward: 4963.22 - Last mean reward per episode: 4688.18
# Num timesteps: 9860000
# Best mean reward: 4963.22 - Last mean reward per episode: 4703.40
# Num timesteps: 9861000
# Best mean reward: 4963.22 - Last mean reward per episode: 4703.62
# Num timesteps: 9862000
# Best mean reward: 4963.22 - Last mean reward per episode: 4678.82
# Num timesteps: 9863000
# Best mean reward: 4963.22 - Last mean reward per episode: 4635.75
# Num timesteps: 9864000
# Best mean reward: 4963.22 - Last mean reward per episode: 4632.81
# Num timesteps: 9865000
# Best mean reward: 4963.22 - Last mean reward per episode: 4632.94
# Num timesteps: 9866000
# Best mean reward: 4963.22 - Last mean reward per episode: 4618.84
# Num timesteps: 9867000
# Best mean reward: 4963.22 - Last mean reward per episode: 4598.50
# Num timesteps: 9868000
# Best mean reward: 4963.22 - Last mean reward per episode: 4600.86
# Num timesteps: 9869000
# Best mean reward: 4963.22 - Last mean reward per episode: 4596.48
# Num timesteps: 9870000
# Best mean reward: 4963.22 - Last mean reward per episode: 4589.55
# Num timesteps: 9871000
# Best mean reward: 4963.22 - Last mean reward per episode: 4553.76
# Num timesteps: 9872000
# Best mean reward: 4963.22 - Last mean reward per episode: 4556.25
# Num timesteps: 9873000
# Best mean reward: 4963.22 - Last mean reward per episode: 4555.88
# Num timesteps: 9874000
# Best mean reward: 4963.22 - Last mean reward per episode: 4599.08
# Num timesteps: 9875000
# Best mean reward: 4963.22 - Last mean reward per episode: 4598.34
# Num timesteps: 9876000
# Best mean reward: 4963.22 - Last mean reward per episode: 4597.70
# Num timesteps: 9877000
# Best mean reward: 4963.22 - Last mean reward per episode: 4597.13
# Num timesteps: 9878000
# Best mean reward: 4963.22 - Last mean reward per episode: 4555.30
# Num timesteps: 9879000
# Best mean reward: 4963.22 - Last mean reward per episode: 4516.76
# Num timesteps: 9880000
# Best mean reward: 4963.22 - Last mean reward per episode: 4477.11
# Num timesteps: 9881000
# Best mean reward: 4963.22 - Last mean reward per episode: 4424.37
# Num timesteps: 9882000
# Best mean reward: 4963.22 - Last mean reward per episode: 4384.23
# Num timesteps: 9883000
# Best mean reward: 4963.22 - Last mean reward per episode: 4386.20
# Num timesteps: 9884000
# Best mean reward: 4963.22 - Last mean reward per episode: 4382.43
# Num timesteps: 9885000
# Best mean reward: 4963.22 - Last mean reward per episode: 4416.50
# Num timesteps: 9886000
# Best mean reward: 4963.22 - Last mean reward per episode: 4381.54
# Num timesteps: 9887000
# Best mean reward: 4963.22 - Last mean reward per episode: 4381.68
# Num timesteps: 9888000
# Best mean reward: 4963.22 - Last mean reward per episode: 4379.85
# Num timesteps: 9889000
# Best mean reward: 4963.22 - Last mean reward per episode: 4380.04
# Num timesteps: 9890000
# Best mean reward: 4963.22 - Last mean reward per episode: 4296.26
# Num timesteps: 9891000
# Best mean reward: 4963.22 - Last mean reward per episode: 4256.65
# Num timesteps: 9892000
# Best mean reward: 4963.22 - Last mean reward per episode: 4242.61
# Num timesteps: 9893000
# Best mean reward: 4963.22 - Last mean reward per episode: 4201.09
# Num timesteps: 9894000
# Best mean reward: 4963.22 - Last mean reward per episode: 4229.39
# Num timesteps: 9895000
# Best mean reward: 4963.22 - Last mean reward per episode: 4270.81
# Num timesteps: 9896000
# Best mean reward: 4963.22 - Last mean reward per episode: 4259.91
# Num timesteps: 9897000
# Best mean reward: 4963.22 - Last mean reward per episode: 4259.36
# Num timesteps: 9898000
# Best mean reward: 4963.22 - Last mean reward per episode: 4221.31
# Num timesteps: 9899000
# Best mean reward: 4963.22 - Last mean reward per episode: 4209.25
# Num timesteps: 9900000
# Best mean reward: 4963.22 - Last mean reward per episode: 4173.49
# Num timesteps: 9901000
# Best mean reward: 4963.22 - Last mean reward per episode: 4212.84
# Num timesteps: 9902000
# Best mean reward: 4963.22 - Last mean reward per episode: 4184.87
# Num timesteps: 9903000
# Best mean reward: 4963.22 - Last mean reward per episode: 4182.89
# Num timesteps: 9904000
# Best mean reward: 4963.22 - Last mean reward per episode: 4199.54
# Num timesteps: 9905000
# Best mean reward: 4963.22 - Last mean reward per episode: 4213.48
# Num timesteps: 9906000
# Best mean reward: 4963.22 - Last mean reward per episode: 4220.25
# Num timesteps: 9907000
# Best mean reward: 4963.22 - Last mean reward per episode: 4216.73
# Num timesteps: 9908000
# Best mean reward: 4963.22 - Last mean reward per episode: 4244.37
# Num timesteps: 9909000
# Best mean reward: 4963.22 - Last mean reward per episode: 4278.38
# Num timesteps: 9910000
# Best mean reward: 4963.22 - Last mean reward per episode: 4298.48
# Num timesteps: 9911000
# Best mean reward: 4963.22 - Last mean reward per episode: 4338.96
# Num timesteps: 9912000
# Best mean reward: 4963.22 - Last mean reward per episode: 4295.06
# Num timesteps: 9913000
# Best mean reward: 4963.22 - Last mean reward per episode: 4269.40
# Num timesteps: 9914000
# Best mean reward: 4963.22 - Last mean reward per episode: 4292.93
# Num timesteps: 9915000
# Best mean reward: 4963.22 - Last mean reward per episode: 4286.88
# Num timesteps: 9916000
# Best mean reward: 4963.22 - Last mean reward per episode: 4285.56
# Num timesteps: 9917000
# Best mean reward: 4963.22 - Last mean reward per episode: 4307.77
# Num timesteps: 9918000
# Best mean reward: 4963.22 - Last mean reward per episode: 4315.71
# Num timesteps: 9919000
# Best mean reward: 4963.22 - Last mean reward per episode: 4312.41
# Num timesteps: 9920000
# Best mean reward: 4963.22 - Last mean reward per episode: 4315.00
# Num timesteps: 9921000
# Best mean reward: 4963.22 - Last mean reward per episode: 4312.56
# Num timesteps: 9922000
# Best mean reward: 4963.22 - Last mean reward per episode: 4349.98
# Num timesteps: 9923000
# Best mean reward: 4963.22 - Last mean reward per episode: 4351.36
# Num timesteps: 9924000
# Best mean reward: 4963.22 - Last mean reward per episode: 4350.02
# Num timesteps: 9925000
# Best mean reward: 4963.22 - Last mean reward per episode: 4343.57
# Num timesteps: 9926000
# Best mean reward: 4963.22 - Last mean reward per episode: 4342.55
# Num timesteps: 9927000
# Best mean reward: 4963.22 - Last mean reward per episode: 4347.57
# Num timesteps: 9928000
# Best mean reward: 4963.22 - Last mean reward per episode: 4351.02
# Num timesteps: 9929000
# Best mean reward: 4963.22 - Last mean reward per episode: 4348.80
# Num timesteps: 9930000
# Best mean reward: 4963.22 - Last mean reward per episode: 4348.74
# Num timesteps: 9931000
# Best mean reward: 4963.22 - Last mean reward per episode: 4254.35
# Num timesteps: 9932000
# Best mean reward: 4963.22 - Last mean reward per episode: 4264.10
# Num timesteps: 9933000
# Best mean reward: 4963.22 - Last mean reward per episode: 4260.61
# Num timesteps: 9934000
# Best mean reward: 4963.22 - Last mean reward per episode: 4302.99
# Num timesteps: 9935000
# Best mean reward: 4963.22 - Last mean reward per episode: 4306.51
# Num timesteps: 9936000
# Best mean reward: 4963.22 - Last mean reward per episode: 4309.11
# Num timesteps: 9937000
# Best mean reward: 4963.22 - Last mean reward per episode: 4290.34
# Num timesteps: 9938000
# Best mean reward: 4963.22 - Last mean reward per episode: 4323.04
# Num timesteps: 9939000
# Best mean reward: 4963.22 - Last mean reward per episode: 4376.21
# Num timesteps: 9940000
# Best mean reward: 4963.22 - Last mean reward per episode: 4379.27
# Num timesteps: 9941000
# Best mean reward: 4963.22 - Last mean reward per episode: 4420.81
# Num timesteps: 9942000
# Best mean reward: 4963.22 - Last mean reward per episode: 4401.90
# Num timesteps: 9943000
# Best mean reward: 4963.22 - Last mean reward per episode: 4405.54
# Num timesteps: 9944000
# Best mean reward: 4963.22 - Last mean reward per episode: 4408.25
# Num timesteps: 9945000
# Best mean reward: 4963.22 - Last mean reward per episode: 4411.34
# Num timesteps: 9946000
# Best mean reward: 4963.22 - Last mean reward per episode: 4409.16
# Num timesteps: 9947000
# Best mean reward: 4963.22 - Last mean reward per episode: 4413.77
# Num timesteps: 9948000
# Best mean reward: 4963.22 - Last mean reward per episode: 4465.20
# Num timesteps: 9949000
# Best mean reward: 4963.22 - Last mean reward per episode: 4463.48
# Num timesteps: 9950000
# Best mean reward: 4963.22 - Last mean reward per episode: 4427.95
# Num timesteps: 9951000
# Best mean reward: 4963.22 - Last mean reward per episode: 4458.56
# Num timesteps: 9952000
# Best mean reward: 4963.22 - Last mean reward per episode: 4464.11
# Num timesteps: 9953000
# Best mean reward: 4963.22 - Last mean reward per episode: 4504.36
# Num timesteps: 9954000
# Best mean reward: 4963.22 - Last mean reward per episode: 4501.63
# Num timesteps: 9955000
# Best mean reward: 4963.22 - Last mean reward per episode: 4475.90
# Num timesteps: 9956000
# Best mean reward: 4963.22 - Last mean reward per episode: 4450.72
# Num timesteps: 9957000
# Best mean reward: 4963.22 - Last mean reward per episode: 4494.98
# Num timesteps: 9958000
# Best mean reward: 4963.22 - Last mean reward per episode: 4516.12
# Num timesteps: 9959000
# Best mean reward: 4963.22 - Last mean reward per episode: 4512.97
# Num timesteps: 9960000
# Best mean reward: 4963.22 - Last mean reward per episode: 4519.07
# Num timesteps: 9961000
# Best mean reward: 4963.22 - Last mean reward per episode: 4524.36
# Num timesteps: 9962000
# Best mean reward: 4963.22 - Last mean reward per episode: 4500.68
# Num timesteps: 9963000
# Best mean reward: 4963.22 - Last mean reward per episode: 4524.75
# Num timesteps: 9964000
# Best mean reward: 4963.22 - Last mean reward per episode: 4509.58
# Num timesteps: 9965000
# Best mean reward: 4963.22 - Last mean reward per episode: 4511.99
# Num timesteps: 9966000
# Best mean reward: 4963.22 - Last mean reward per episode: 4514.55
# Num timesteps: 9967000
# Best mean reward: 4963.22 - Last mean reward per episode: 4515.59
# Num timesteps: 9968000
# Best mean reward: 4963.22 - Last mean reward per episode: 4513.99
# Num timesteps: 9969000
# Best mean reward: 4963.22 - Last mean reward per episode: 4514.15
# Num timesteps: 9970000
# Best mean reward: 4963.22 - Last mean reward per episode: 4524.94
# Num timesteps: 9971000
# Best mean reward: 4963.22 - Last mean reward per episode: 4528.33
# Num timesteps: 9972000
# Best mean reward: 4963.22 - Last mean reward per episode: 4529.70
# Num timesteps: 9973000
# Best mean reward: 4963.22 - Last mean reward per episode: 4573.01
# Num timesteps: 9974000
# Best mean reward: 4963.22 - Last mean reward per episode: 4567.87
# Num timesteps: 9975000
# Best mean reward: 4963.22 - Last mean reward per episode: 4621.34
# Num timesteps: 9976000
# Best mean reward: 4963.22 - Last mean reward per episode: 4660.47
# Num timesteps: 9977000
# Best mean reward: 4963.22 - Last mean reward per episode: 4659.22
# Num timesteps: 9978000
# Best mean reward: 4963.22 - Last mean reward per episode: 4662.28
# Num timesteps: 9979000
# Best mean reward: 4963.22 - Last mean reward per episode: 4663.79
# Num timesteps: 9980000
# Best mean reward: 4963.22 - Last mean reward per episode: 4698.07
# Num timesteps: 9981000
# Best mean reward: 4963.22 - Last mean reward per episode: 4685.95
# Num timesteps: 9982000
# Best mean reward: 4963.22 - Last mean reward per episode: 4647.31
# Num timesteps: 9983000
# Best mean reward: 4963.22 - Last mean reward per episode: 4627.31
# Num timesteps: 9984000
# Best mean reward: 4963.22 - Last mean reward per episode: 4669.30
# Num timesteps: 9985000
# Best mean reward: 4963.22 - Last mean reward per episode: 4703.46
# Num timesteps: 9986000
# Best mean reward: 4963.22 - Last mean reward per episode: 4743.31
# Num timesteps: 9987000
# Best mean reward: 4963.22 - Last mean reward per episode: 4737.53
# Num timesteps: 9988000
# Best mean reward: 4963.22 - Last mean reward per episode: 4735.08
# Num timesteps: 9989000
# Best mean reward: 4963.22 - Last mean reward per episode: 4736.46
# Num timesteps: 9990000
# Best mean reward: 4963.22 - Last mean reward per episode: 4737.78
# Num timesteps: 9991000
# Best mean reward: 4963.22 - Last mean reward per episode: 4737.30
# Num timesteps: 9992000
# Best mean reward: 4963.22 - Last mean reward per episode: 4719.23
# Num timesteps: 9993000
# Best mean reward: 4963.22 - Last mean reward per episode: 4739.43
# Num timesteps: 9994000
# Best mean reward: 4963.22 - Last mean reward per episode: 4773.05
# Num timesteps: 9995000
# Best mean reward: 4963.22 - Last mean reward per episode: 4772.49
# Num timesteps: 9996000
# Best mean reward: 4963.22 - Last mean reward per episode: 4794.34
# Num timesteps: 9997000
# Best mean reward: 4963.22 - Last mean reward per episode: 4762.57
# Num timesteps: 9998000
# Best mean reward: 4963.22 - Last mean reward per episode: 4764.27
# Num timesteps: 9999000
# Best mean reward: 4963.22 - Last mean reward per episode: 4763.91
# Num timesteps: 10000000
# Best mean reward: 4963.22 - Last mean reward per episode: 4765.51

# %%
# Load the trained agent
# NOTE: if you have loading issue, you can pass `print_system_info=True`
# to compare the system on which the model was trained vs the current one
# model = DQN.load("dqn_lunar", env=env, print_system_info=True)
env = gym.make(env_name,render_mode='human')
model = PPO.load("./tmp/gym/20230417-224635_Ant-v4.zip", env=env)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render()
# Out:
# Pressed ESC
# Quitting.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 12
#      10 for i in range(1000):
#      11     action, _state = model.predict(obs, deterministic=True)
# ---> 12     obs, reward, done, info = vec_env.step(action)
#      13     vec_env.render()
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:171, in VecEnv.step(self, actions)
#     164 """
#     165 Step the environments with the given action
#     166
#     167 :param actions: the action
#     168 :return: observation, reward, done, information
#     169 """
#     170 self.step_async(actions)
# --> 171 return self.step_wait()
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:57, in DummyVecEnv.step_wait(self)
#      54 def step_wait(self) -> VecEnvStepReturn:
#      55     # Avoid circular imports
#      56     for env_idx in range(self.num_envs):
# ---> 57         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      58             self.actions[env_idx]
#      59         )
#      60         # convert to SB3 VecEnv api
#      61         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/wrappers/env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/envs/mujoco/ant_v4.py:349, in AntEnv.step(self, action)
#     346 reward = rewards - costs
#     348 if self.render_mode == "human":
# --> 349     self.render()
#     350 return observation, reward, terminated, False, info
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_env.py:379, in MujocoEnv.render(self)
#     378 def render(self):
# --> 379     return self.mujoco_renderer.render(
#     380         self.render_mode, self.camera_id, self.camera_name
#     381     )
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:673, in MujocoRenderer.render(self, render_mode, camera_id, camera_name)
#     670     return img
#     672 elif render_mode == "human":
# --> 673     return viewer.render()
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:402, in WindowViewer.render(self)
#     400 if self._paused:
#     401     while self._paused:
# --> 402         update()
#     403         if self._advance_by_one_step:
#     404             self._advance_by_one_step = False
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:353, in WindowViewer.render.<locals>.update()
#     351 def update():
#     352     # fill overlay items
# --> 353     self._create_overlay()
#     355     render_start = time.time()
#     356     if self.window is None:
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:576, in WindowViewer._create_overlay(self)
#     574         self.add_overlay(topleft, "Stop", "[Space]")
#     575     else:
# --> 576         self.add_overlay(topleft, "Start", "[Space]")
#     577         self.add_overlay(
#     578             topleft, "Advance simulation by one step", "[right arrow]"
#     579         )
#     580 self.add_overlay(
#     581     topleft, "Referenc[e] frames", "On" if self.vopt.frame == 1 else "Off"
#     582 )
#
# File ~/miniconda3/envs/d3/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:71, in BaseRender.add_overlay(self, gridpos, text1, text2)
#      68 def make_context_current(self):
#      69     raise NotImplementedError
# ---> 71 def add_overlay(self, gridpos: int, text1: str, text2: str):
#      72     """Overlays text on the scene."""
#      73     if gridpos not in self._overlays:
#
# KeyboardInterrupt:
